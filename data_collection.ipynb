# %% [markdown]
# # Data Collection from APIs

# %%
import asyncio
import aiohttp
import json
import pandas as pd

# %% [markdown]
# ## Collecting Data From Four Data Sources
# - apps_json() collects data from steam's official api where we get App name and id
# - steamspy_json() collects data from steam and is a third party steam observer where we get multiple metrics and info such as ratings, reviews, etc.
# - steamhf_json() collects data from steam and is a third party steam observer where it is very similar to steamspy but different in that it brings in different info such as genres, categories, and tags
# - gamalytic_json() is another 3rd party steam observer which is gets two metrics, the class of the publisher which entails how high tier a game it is and the amount of copies sold of the game

# %%
async def fetch(session, url):
    try:
        async with session.get(url) as response:
            if response.status == 200:
                return await response.text()
            else:
                print(f"Failed to fetch {url}: Status {response.status}")
                return None
    except Exception as e:
        print(f"Exception occurred while fetching {url}: {e}")
        return None

async def apps_json():
    game_id_url = "https://api.steampowered.com/ISteamApps/GetAppList/v2/"
    async with aiohttp.ClientSession() as session:
        response_id = await fetch(session, game_id_url)
        if response_id:
            game_dict = json.loads(response_id)['applist']['apps']
            return game_dict
        return {}

async def steamspy_json():
    steamspy_dict = dict()
    index = 0
    page = 0
    steamspy_columns = ['appid', 'positive', 'negative', 
                        'userscore', 'score_rank', 'price', 
                        'owners', 'ccu', 'developer', 'publisher']
    
    async with aiohttp.ClientSession() as session:
        while True:
            steamspy_url = f"https://steamspy.com/api.php?request=all&page={page}"
            steamspy_response_text = await fetch(session, steamspy_url)
            if steamspy_response_text:
                steamspy_json = json.loads(steamspy_response_text)
                if not steamspy_json:
                    break
                for i in steamspy_json:
                    app = steamspy_json[i]
                    info = {element: str(app[element]) for element in steamspy_columns}
                    steamspy_dict[index] = info
                    index += 1
                page += 1
            else:
                break
        
    return steamspy_dict

async def steamhf_json():
    steamhf_columns = ['AppID', 'Estimated owners', 'Price', 
                    'Metacritic score', 'User score', 'Positive', 'Negative', 
                    'Recommendations', 'Categories', 'Tags', 'Peak CCU', 'Genres' ]
    steamhf_dict = dict()
    offset = 0
    index = 0
    
    async with aiohttp.ClientSession() as session:
        while True:
            steamhf_url = f"https://datasets-server.huggingface.co/rows?dataset=FronkonGames%2Fsteam-games-dataset&config=default&split=train&offset={offset}&length=100"
            steamhf_response_text = await fetch(session, steamhf_url)
            if steamhf_response_text:
                steamhf_json = json.loads(steamhf_response_text)
                rows = steamhf_json.get('rows', [])
                if not rows:
                    break
                for i in range(len(rows)):
                    row_info = {column.lower(): rows[i]['row'][column] for column in steamhf_columns}
                    steamhf_dict[index] = row_info
                    index += 1
                offset += 100
            else:
                break
        
    return steamhf_dict

async def gamalytic_json():
    gamalytic_cols = ['steamId', 'publisherClass', 'copiesSold']
    gamalytic_dict = dict()
    page = 0
    index = 0
    
    async with aiohttp.ClientSession() as session:
        while True:
            gamalytic_url = f"https://api.gamalytic.com/steam-games/list?page={page}&fields=copiesSold,publisherClass,steamId"
            gamalytic_response_text = await fetch(session, gamalytic_url)
            if gamalytic_response_text:
                gamalytic_json = json.loads(gamalytic_response_text)
                results = gamalytic_json.get('result', [])
                if not results:
                    break
                gamalytic_data = [{col.lower(): result.get(col, None) for col in gamalytic_cols} for result in results]
                for row in gamalytic_data:
                    gamalytic_dict[index] = row
                    index += 1
                page += 1
            else:
                break
        
    return gamalytic_dict

# %% [markdown]
# ## General View of each DataFrame

# %%
apps_df = pd.DataFrame(await apps_json())
apps_df['appid'] = apps_df['appid'].astype(int)
print(apps_df.shape)
apps_df.sample(n=5)
# Out:
# (202864, 2)
#           appid                 name
# 187553  1624080           sfäre Demo
# 148482  1022610  Alchemic DungeonsDX
# 58680   1879930           Naiad Demo
# 178156  2410130             GateTail
# 83577   1315280       PositronX Demo

# %%
steamhf_df = pd.DataFrame((await steamhf_json()).values())
steamhf_df['appid'] = steamhf_df['appid'].astype(int)
print(steamhf_df.shape)
steamhf_df.sample(n=5)
# Out:
# (83560, 12)
#          appid estimated owners  price  metacritic score  user score  \
# 32581  1164480        0 - 20000  14.99                 0           0
# 63903  1966500            0 - 0   0.00                 0           0
# 2170    445350        0 - 20000  14.99                 0           0
# 172     763350        0 - 20000   2.99                 0           0
# 6580    562310        0 - 20000   2.99                 0           0
#
#        positive  negative  recommendations  \
# 32581        10         2                0
# 63903         0         0                0
# 2170          7        10                0
# 172           8         1                0
# 6580         11         1                0
#
#                                               categories  \
# 32581  Single-player,Steam Achievements,Full controll...
# 63903  Multi-player,PvP,Online PvP,Co-op,Online Co-op...
# 2170   Single-player,Multi-player,PvP,Online PvP,Co-o...
# 172    Single-player,Multi-player,PvP,Shared/Split Sc...
# 6580   Single-player,Steam Achievements,Full controll...
#
#                                                     tags  peak ccu  \
# 32581  RPG,RPGMaker,JRPG,Dating Sim,Farming Sim,LGBTQ...         0
# 63903                                               None         0
# 2170   Strategy,Action,Early Access,Simulation,Co-op,...         0
# 172                           Casual,Action,Sports,Indie         0
# 6580                                 Action,Indie,Casual         0
#
#                                         genres
# 32581                                      RPG
# 63903                    Free to Play,Strategy
# 2170   Action,Simulation,Strategy,Early Access
# 172                 Action,Casual,Indie,Sports
# 6580                       Action,Casual,Indie

# %%
steamspy_df = pd.DataFrame((await steamspy_json()).values())
steamspy_df['appid'] = steamspy_df['appid'].astype(int)
print(steamspy_df.shape)
steamspy_df.sample(n=5)
# Out:
# Failed to fetch https://steamspy.com/api.php?request=all&page=74: Status 500
# (73467, 10)
#          appid positive negative userscore score_rank price  \
# 1394   1328660     7455     1829         0             2999
# 55162  1289170        7        0         0              999
# 51583   298420       12        6         0              599
# 5413   1282150     2317      171         0             3999
# 63652   839940       25        1         0              799
#
#                      owners  ccu                      developer  \
# 1394   500,000 .. 1,000,000  192  Stellar Entertainment Limited
# 55162           0 .. 20,000    0                   Jura Ex Alto
# 51583           0 .. 20,000    0                   Etter Studio
# 5413     100,000 .. 200,000   25                    Purple Lamp
# 63652           0 .. 20,000    1                Choice of Games
#
#              publisher
# 1394   Electronic Arts
# 55162     Jura Ex Alto
# 51583     Etter Studio
# 5413        THQ Nordic
# 63652  Choice of Games

# %%
gamalytic_df = pd.DataFrame((await gamalytic_json()).values())
gamalytic_df = gamalytic_df.rename(columns={'steamid': 'appid'})
gamalytic_df['appid'] = gamalytic_df['appid'].astype(int)
print(gamalytic_df.shape)
gamalytic_df.sample(n=5)
# Out:
# (82277, 3)
#          appid publisherclass  copiessold
# 68278  1867490       Hobbyist           1
# 80293  2528860          Indie        7311
# 51350  1792770       Hobbyist          25
# 4360   1249040             AA       38632
# 75011  1069220       Hobbyist        1046

# %% [markdown]
# ## Merging All Dataframes Into Primary Dataset

# %%
df = pd.merge(steamspy_df, gamalytic_df, how='left', on='appid')
print(df.shape)
df.sample(n=5)
# Out:
# (73467, 12)
#          appid positive negative userscore score_rank price            owners  \
# 69961  2789380        1        0         0              399       0 .. 20,000
# 51024  1065050        1        2         0              199       0 .. 20,000
# 43946  1051320        1        2         0              299       0 .. 20,000
# 18169  1756120       34       63         0               99  20,000 .. 50,000
# 22070  1755300      136       54         0              149  20,000 .. 50,000
#
#       ccu                developer               publisher publisherclass  \
# 69961   0               Deez Games              Deez Games       Hobbyist
# 51024   0              Sonic-Alpha                      NS       Hobbyist
# 43946   0                 IO Games                IO Games          Indie
# 18169   0               Boom Games              Boom Games          Indie
# 22070   3  Turquoise Revival Games  GrabTheGames, IndieArk          Indie
#
#        copiessold
# 69961        15.0
# 51024        54.0
# 43946        36.0
# 18169      2822.0
# 22070      6509.0

# %%
df = pd.merge(df, steamhf_df, how='left', on='appid')
print(df.shape)
df.sample(n=5)
# Out:
# (73467, 34)
#          appid positive_x negative_x userscore score_rank price_x  \
# 58334  1352870          3          2         0                399
# 62473  2798810          5          2         0                949
# 19675   328440         43         53         0                699
# 73221  1648760         46          3         0               1999
# 19860   604920         15          1         0                999
#
#                  owners ccu       developer                 publisher  ...  \
# 58334       0 .. 20,000   0      Droid Riot            Conglomerate 5  ...
# 62473       0 .. 20,000   1    Denzee Games              Denzee Games  ...
# 19675  20,000 .. 50,000   4  Accolade, Inc.  Atari, Nightdive Studios  ...
# 73221       0 .. 20,000   1         sqr3lab                   sqr3lab  ...
# 19860  20,000 .. 50,000   0            Omaj               Blossomsoft  ...
#
#        price  metacritic score_y user score_y  positive  negative  \
# 58334   4.99                 0.0          0.0       0.0       0.0
# 62473    NaN                 NaN          NaN       NaN       NaN
# 19675   1.39                 0.0          0.0      30.0      51.0
# 73221  16.99                 0.0          0.0       0.0       0.0
# 19860   9.99                 0.0          0.0      14.0       1.0
#
#        recommendations_y                                       categories_y  \
# 58334                0.0                                      Single-player
# 62473                NaN                                                NaN
# 19675                0.0                                      Single-player
# 73221                0.0              Single-player,Full controller support
# 19860                0.0  Single-player,Steam Achievements,Full controll...
#
#                                                   tags_y  peak ccu_y  \
# 58334                                               None         0.0
# 62473                                                NaN         NaN
# 19675                         Strategy,Turn-Based,Sci-fi         0.0
# 73221                                               None         2.0
# 19860  RPG,JRPG,Singleplayer,Pixel Graphics,Drama,RPG...         0.0
#
#                                 genres_y
# 58334                             Action
# 62473                                NaN
# 19675                           Strategy
# 73221  Adventure,Simulation,Early Access
# 19860                                RPG
#
# [5 rows x 34 columns]

# %%
df = pd.merge(df, apps_df, how='left', on='appid')
print(df.shape)
df.sample(n=5)
# Out:
# (73467, 35)
#          appid positive_x negative_x userscore score_rank price_x  \
# 56695  1238720          5          1         0                 99
# 41961  2433910          1          1         0               1499
# 41784  1932260        163         22         0               1999
# 13179  1218170        357        133         0                699
# 25699   362920         33         62         0                399
#
#                  owners ccu                  developer  \
# 56695       0 .. 20,000   0             EmotionalMingo
# 41961       0 .. 20,000   0     Brothers Grimm Studios
# 41784       0 .. 20,000   6          MinMax Games Ltd.
# 13179  20,000 .. 50,000   2                    漫森游戏工作室
# 25699       0 .. 20,000   0  Cryo Interactive, Koalabs
#
#                     publisher  ... metacritic score_y  user score_y positive  \
# 56695          EmotionalMingo  ...                0.0           0.0      4.0
# 41961  Brothers Grimm Studios  ...                0.0           0.0      0.0
# 41784       MinMax Games Ltd.  ...                0.0           0.0     52.0
# 13179                 漫森游戏工作室  ...                0.0           0.0    261.0
# 25699                Microids  ...                0.0           0.0     25.0
#
#        negative  recommendations_y  \
# 56695       1.0                0.0
# 41961       0.0                0.0
# 41784       9.0                0.0
# 13179      88.0              292.0
# 25699      55.0                0.0
#
#                                             categories_y  \
# 56695                                      Single-player
# 41961                    Multi-player,Co-op,Online Co-op
# 41784  Single-player,Multi-player,Co-op,Online Co-op,...
# 13179                                      Single-player
# 25699                                      Single-player
#
#                                                   tags_y  peak ccu_y  \
# 56695  Indie,Adventure,Platformer,Shooter,Beautiful,F...         0.0
# 41961                                               None         0.0
# 41784  Early Access,Tower Defense,Strategy,Singleplay...        25.0
# 13179  Horror,Psychological Horror,Adventure,Historic...         7.0
# 25699                            Adventure,Point & Click         1.0
#
#                                            genres_y  \
# 56695                               Adventure,Indie
# 41961                     Action,Indie,Early Access
# 41784                         Strategy,Early Access
# 13179  Action,Adventure,Casual,Indie,RPG,Simulation
# 25699                                     Adventure
#
#                               name
# 56695  Wandering Through The Vines
# 41961            Escape The Office
# 41784     No Creeps Were Harmed TD
# 13179             回门 Way Back Home
# 25699  Atlantis 2: Beyond Atlantis
#
# [5 rows x 35 columns]

# %%
columns = ['appid', 'name', 'positive_x', 'negative_x',
           'price_y', 'copiessold', 'metacritic score_x', 'recommendations_x',
           'ccu', 'peak ccu_x', 'developer', 'publisher', 'publisherclass',
            'categories_x', 'tags_x', 'genres_x']
columns_formatted = ['appid', 'name', 'positive', 'negative',
           'price', 'copies_sold', 'metacritic_score', 'recommendations',
           'current_users', 'peak_users', 'developer', 'publisher', 'publisherclass',
            'categories', 'tags', 'genres']

df = df[columns]
df = df.rename(columns={columns[i]:columns_formatted[i] for i in range(len(columns))})

# %%
df.sample(n=5)
# Out:
#          appid                  name positive negative  price  copies_sold  \
# 3702    497640         Trick & Treat     2186       85   0.00     196891.0
# 72437   972910              Timore 6       31        7   9.99       1365.0
# 11723   347510                   NaN      246       39   0.00          NaN
# 7681   1889650       Jigsaw Bestiary       32        1   1.99        775.0
# 21845  2103660  Bugz Bows and Curses        1        0    NaN          1.0
#
#        metacritic_score  recommendations current_users  peak_users  \
# 3702                0.0              0.0             2         3.0
# 72437               0.0              0.0             0         0.0
# 11723               0.0            132.0             0         0.0
# 7681                0.0              0.0             2         1.0
# 21845               NaN              NaN             0         NaN
#
#               developer         publisher publisherclass  \
# 3702           Rabbiton          Rabbiton          Indie
# 72437   Vidas Salavejus   Vidas Salavejus          Indie
# 11723    Citeremis Inc.    Citeremis Inc.            NaN
# 7681   Minicactus Games  Minicactus Games          Indie
# 21845      Prestosilver      Prestosilver       Hobbyist
#
#                                               categories  \
# 3702        Single-player,Steam Achievements,Steam Cloud
# 72437                                      Single-player
# 11723  Single-player,Steam Achievements,Full controll...
# 7681        Single-player,Steam Achievements,Steam Cloud
# 21845                                                NaN
#
#                                                     tags  \
# 3702   Free to Play,RPGMaker,Pixel Graphics,Adventure...
# 72437  Indie,Gore,Violent,Nudity,Horror,Psychological...
# 11723                 Indie,Action,Casual,Arcade,Stealth
# 7681   Puzzle,Tabletop,Hand-drawn,Mythology,Historica...
# 21845                                                NaN
#
#                                     genres
# 3702   Adventure,Casual,Free to Play,Indie
# 72437                                Indie
# 11723                  Action,Casual,Indie
# 7681                                Casual
# 21845                                  NaN

# %%
df.to_excel('steam_sales.xlsx', index=False)
